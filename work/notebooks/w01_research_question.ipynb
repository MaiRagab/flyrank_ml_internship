# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MaiRagab/flyrank_ml_internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose the Content Refresh lane because it focuses on identifying pages that may benefit from content updates. This can help prioritize which pages should be reviewed first based on their search performance. I chose this lane because it supports practical, data-driven decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## Research Question
#
# Question: Which pages should be prioritized for content refresh to improve search performance?
#
# Decision: Decide which pages should be reviewed first.
#
# Who acts on it? The SEO specialist or content manager.
#
# Action: Review and update the selected pages before others.
#
# Cost of a wrong recommendation: Time and effort may be spent updating pages that do not need changes while more important pages could be missed.
#
# Why data or ML helps: Search performance data can help identify useful patterns that support better prioritization decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ## Quick look at the data
#
# I will examine a few summary statistics from the starter dataset to understand its size and characteristics. These numbers will help justify why the Content Refresh lane is worth exploring during the internship.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("/content/flyrank_ml_internship/data/raw/content_refresh_anonymized.csv")

print("Number of pages:", len(df))
print("Number of columns:", len(df.columns))
print("Average CTR:", round(df["ctr"].mean(), 2))
# Out:
# Number of pages: 30000
# Number of columns: 44
# Average CTR: 0.51

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project provides observed and data-supported insights about which pages may benefit from a content refresh. The results are directional and intended to support decision-making. This project does not prove causation and does not predict Google's ranking algorithm.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %%
# !git clone https://github.com/MaiRagab/flyrank_ml_internship.git
# %cd flyrank_ml_internship
# Out:
# Cloning into 'flyrank_ml_internship'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 123 (delta 38), reused 93 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (123/123), 1.85 MiB | 14.57 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# /content/flyrank_ml_internship/flyrank_ml_internship

# %%
import os
print(os.listdir("data/raw"))
# Out:
# ['content_refresh_anonymized.csv']

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Number of pages:", len(df))
print("Number of columns:", len(df.columns))
print(df.head())
# Out:
# Number of pages: 30000
# Number of columns: 44
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
# ...
