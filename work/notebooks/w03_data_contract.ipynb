# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MaiRagab/flyrank_ml_internship/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# **Unit of analysis:**
# One row represents one content page in the selected dataset.
#
# **Time window:**
# I will use one mid-panel month (2026-03) for analysis and feature creation, as recommended in the assignment. This helps avoid using the final month as a development set.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
# !git clone https://github.com/MaiRagab/flyrank_ml_internship.git
# %cd flyrank_ml_internship
# Out:
# Cloning into 'flyrank_ml_internship'...
# remote: Enumerating objects: 133, done.
# remote: Counting objects: 100% (133/133), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 133 (delta 45), reused 91 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (133/133), 1.85 MiB | 10.67 MiB/s, done.
# Resolving deltas: 100% (45/45), done.
# /content/flyrank_ml_internship

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# ### Features
# - ctr
# - avg_position
# - impressions_90d
# - clicks_90d
# - content_age_days
#
# ### Label / Proxy
# - content_refresh_needed (proxy label indicating whether a page may need a content refresh)
#
# ### Context
# - content_id
# - client_id
# - month
#
# ### Excluded
# - trend_pct (excluded because it may contain future information and could introduce data leakage)

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("/content/flyrank_ml_internship/data/raw/content_refresh_anonymized.csv")

# Query 1: Grain
print("One row represents one content page.")
print("Unique content IDs:", df["content_id"].nunique())

# Query 2: Row count
print("Total rows:", len(df))

# Query 3: Missing values
print("\nMissing values:")
print(df[["ctr", "avg_position", "content_age_days"]].isna().sum())
# Out:
# One row represents one content page.
# Unique content IDs: 30000
# Total rows: 30000
#
# Missing values:
# ctr                 0
# avg_position        0
# content_age_days    0
# dtype: int64

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# ### Data limits
#
# This dataset cannot prove that a content update directly causes better search performance. It also cannot explain all ranking changes because external factors, such as search engine updates and user behavior, are not included. The results should be used as decision support, not as causal proof.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
